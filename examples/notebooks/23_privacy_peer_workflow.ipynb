# %% [markdown]
# # Privacy workflow — peer exploitation · red team · DP robustness
#
# This is the end-to-end pipeline triggered by the researcher's privacy workflow prompt. Stage 1 models an attacker who is a *peer in the distribution* (holding their own data from the same population at different coverage levels); Stage 2 hunts corner cases with the red-team MCP tools; Stage 3 releases the exploited aggregates under Laplace DP and re-runs the attacks to measure robustness. A full audit trail is written to examples/privacy/reports/.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd()))

exec(open('examples/privacy/run_peer_exploitation.py').read())
